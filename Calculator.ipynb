# %% [markdown]
# <a href="https://colab.research.google.com/github/ramya-rk02/Simple-Calculator/blob/main/Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#---------- A gift to Mankind-----------



def add():
  print("Addition")
  no = float (input("Enter the number: "))
  tot = 0
  ans = 0
  while no != 0:
    ans = ans + no
    tot+=1
    no = float (input("Enter the other number (or 0 to calculate): "))
  return [ans,tot]


#Subtraction 

def sub():
  print("Subtraction")
  no = float (input("Enter the number: "))

  tot = 0
  ans = 0
  while no != 0:
    ans = no - ans 
    tot+=1
    no = float (input("Enter the other number (or 0 to calculate): "))
    
  return [0-ans,tot]


#Multiplication

def mul():
  print("Multiplication")
  no = float (input("Enter the number: "))
  tot = 0
  ans = 1
  while no != 0:
    ans = ans*no
    tot+=1
    no = float (input("Enter the other number (or 0 to calculate): "))
  return [ans,tot]


#Division

def div():
  print("Division")
  n = float (input("Enter the number: "))
  a = float (input("Enter the other number: "))
  tot = 2
  ans = n/a 
  return [ans,tot]


#remainder 

def rem():
  print("Remainder")
  n = float (input("Enter the number: "))
  a = float(input("Enter the other number: "))
  tot = 2
  ans = n%a
  return [ans,tot]


#Average

def avg():
  print("Average")
  a = []
  a = add()
  tot = a[1]
  an = a[0]
  ans = an/tot
  return [ans,tot]

#main

print("Hi there mortal. This is Ava. I am from an intergalactic dimension. You obviously don't understand that. ")
  
print("Anyhow, I am here to give you  one of the greatest devices known to my kind. It is called a calcuulatoor. Now follow what we say and learn.  ")

while True:
  list = []
  
 
  print(" Enter 'a' for addition")
  print(" Enter 's' for substraction")
  print(" Enter 'm' for multiplication")
  print(" Enter 'd' for division")
  print(" Enter 'r' for remainder")
  print(" Enter 'avg' for average")
  print(" Enter 'q' for quit")

  o = input(" ")

  if o != 'q':
    if o == 'a':
      list = add() 
      print("Your answer ", list[0], "Total Inputs ", list[1])
    elif o == 's':
      list = sub()
      print("Your answer ", list[0], "Total Inputs ", list[1])
    elif o == 'm':
      list = mul()
      print("Your answer ", list[0], "Total Inputs ", list[1])
    elif o == 'd':
      list = div()
      print("Your answer ", list[0], "Total Inputs ", list[1])
    elif o == 'r':
      list = rem()
      print("Your answer ", list[0], "Total Inputs ", list[1])
    elif o == 'avg':
      list = avg()
      print("Your answer ", list[0], "Total Inputs ", list[1])
  
  else:
    break
# Out:
# Hi there mortal. This is Ava. I am from an intergalactic dimension. You obviously don't understand that.
# Anyhow, I am here to give you  one of the greatest devices known to my kind. It is called a calcuulatoor. Now follow what we say and learn.
#  Enter 'a' for addition
#  Enter 's' for substraction
#  Enter 'm' for multiplication
#  Enter 'd' for division
#  Enter 'r' for remainder
#  Enter 'avg' for average
#  Enter 'q' for quit
#  a
# Addition
# Enter the number: 50
# Enter the other number (or 0 to calculate): 40
# Enter the other number (or 0 to calculate): 30
# Enter the other number (or 0 to calculate): 0
# Your answer  120.0 Total Inputs  3
#  Enter 'a' for addition
#  Enter 's' for substraction
#  Enter 'm' for multiplication
#  Enter 'd' for division
#  Enter 'r' for remainder
#  Enter 'avg' for average
#  Enter 'q' for quit
#  s
# Subtraction
# Enter the number: 50
# Enter the other number (or 0 to calculate): 40
# Enter the other number (or 0 to calculate): 0
# ...
